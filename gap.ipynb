# %%
import matplotlib.pyplot as plt
import numpy as np

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf',  
            '#7f7f7f', '#e377c2', '#8c564b', '#bcbd22']
ecolors = ['#aec7e8', '#ffbb78', '#98df8a', '#ff9896', '#c5b0d5', '#9edae5', 
            '#c7c7c7', '#f7b6d2', '#c49c94', '#dbdb8d']
            
tex_fonts = {
    "font.family": "serif",
    'font.variant': "small-caps",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 12,
    "font.size": 10,
    "legend.fontsize": 8,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,

    "lines.linewidth":2.,
    "lines.markersize":4,
    
    "axes.grid": True, 
    "grid.color": ".9", 
    "grid.linestyle": "--",

    "axes.linewidth":1.5, 
    'axes.facecolor': 'white',
    'axes.edgecolor': 'black',
    'savefig.facecolor': 'white'
}        

# plt.style.use('fivethirtyeight')
plt.rcParams.update(tex_fonts)
plt.rcParams['figure.dpi'] = 600

# style={ 0:'-', 1: '-', 2:'-.', 3:'--',  4:':', 5:'-.', 6:'--', 7: ':'}
style={ 0:'--', 1: '-', 3:':', 4:'dashdot',  2:'-', -1:'-'}
color={ 0:'C2', 1: 'C3', 3: 'C0', 4:'C1', 5:'C4', 2:'C5'}

linestyle_tuple = ['-', ':', '-.', '--', '-.','-']
markers = ["*", "+", ".",  "x", "d", "p", "|"]

# %%
alpha = 0.8;  markevery=5; figsize=(6,3)

labels = []
x= []

aig_train_acc_list = []
aig_val_acc_list = []
port_train_acc_list = []
port_val_acc_list = []
heter_train_acc_list = []
heter_val_acc_list = []


fig, axes = plt.subplots(1, 1, sharex=False, sharey=False, figsize=figsize)
axes.grid(False)

# plot dots
# for i, y in enumerate([aig_train_acc_list, aig_val_acc_list, port_train_acc_list, port_val_acc_list, heter_train_acc_list, heter_val_acc_list]):
#     axes.plot(x, y, color=colors[i], label=labels[i], linestyle=linestyle_tuple[i], marker=markers[i], markevery=markevery, alpha=1)
    
mc1 = (1.0, 0.0, 0.0)  # 红色
mc2 = (0.5, 0.0, 0.5)  # 紫色
mc3 = (0.0, 0.0, 1.0)  # 蓝色

plt.fill_between(x, aig_train_acc_list, aig_val_acc_list, color=mc1, alpha = 0.6, label=labels[0])
plt.fill_between(x, port_train_acc_list, port_val_acc_list, color=mc2, alpha = 0.6, label=labels[1])
plt.fill_between(x, heter_train_acc_list, heter_val_acc_list, color=mc3, alpha = 0.6, label=labels[2])

axes.set_xlabel('Times', fontsize='large')
axes.set_ylabel('Accuracy(%)', fontsize='large')
axes.ticklabel_format(style='sci',scilimits=(0,0),axis='y')
# axes.legend(loc = 'upper right', fancybox = False, shadow = False)
axes.legend(loc = 'lower right', fancybox = False, shadow = False)

fig.savefig ('random-gap-area-5.pdf', bbox_inches= 'tight', pad_inches=0)
fig.show()
