# %%
import matplotlib.pyplot as plt
import numpy as np

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf',  
            '#7f7f7f', '#e377c2', '#8c564b', '#bcbd22']
ecolors = ['#aec7e8', '#ffbb78', '#98df8a', '#ff9896', '#c5b0d5', '#9edae5', 
            '#c7c7c7', '#f7b6d2', '#c49c94', '#dbdb8d']
            
tex_fonts = {
    "font.family": "serif",
    'font.variant': "small-caps",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 12,
    "font.size": 10,
    "legend.fontsize": 8,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,

    "lines.linewidth":2.,
    "lines.markersize":4,
    
    "axes.grid": True, 
    "grid.color": ".9", 
    "grid.linestyle": "--",

    "axes.linewidth":1.5, 
    'axes.facecolor': 'white',
    'axes.edgecolor': 'black',
    'savefig.facecolor': 'white'
}        

# plt.style.use('fivethirtyeight')
plt.rcParams.update(tex_fonts)
plt.rcParams['figure.dpi'] = 600

# style={ 0:'-', 1: '-', 2:'-.', 3:'--',  4:':', 5:'-.', 6:'--', 7: ':'}
style={ 0:'--', 1: '-', 3:':', 4:'dashdot',  2:'-', -1:'-'}
color={ 0:'C2', 1: 'C3', 3: 'C0', 4:'C1', 5:'C4', 2:'C5'}

linestyle_tuple = ['-', ':', '-.', '--', '-.','-']
markers = ["*", "+", ".",  "x", "d", "p", "|"]

# %%
figsize=(8,2)

TODO: add data here
labels = []
cases = []
compress_nodes = []
compress_depth = []

# Setting the positions and width for the bars
bar_width = 0.3
index = np.arange(len(labels))

# Plotting grouped bar chart
fig, ax = plt.subplots(1, 1, sharex=False, sharey=False, figsize=figsize)
ax.grid(False)

bar1 = ax.bar(index, compress_nodes, bar_width, label=cases[0], alpha=0.8)
bar2 = ax.bar(index + bar_width, compress_depth, bar_width, label=cases[1], alpha=0.8)

plt.tick_params(axis='x', labelsize=4) # 调整x轴的字体大小
plt.tick_params(axis='y', labelsize=6) # 调整x轴的字体大小

# Adding chart title and axis labels
ax.set_ylabel('Compress Ratio(%)', fontsize=7)
ax.set_xlabel('Designs', fontsize=7)
ax.set_xticks(index + bar_width / 2)
# ax.set_xticklabels(labels)

# 旋转角度
ax.set_xticklabels(labels, rotation=45, ha="right", rotation_mode="anchor")

# Adding legend
ax.legend(loc = 'upper right', fancybox = True, shadow = False, prop={'size': 6})

# Showing the plot
fig.savefig ('compression-w.pdf', bbox_inches= 'tight', pad_inches=0)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 16
#      13 fig, ax = plt.subplots(1, 1, sharex=False, sharey=False, figsize=figsize)
#      14 ax.grid(False)
# ---> 16 bar1 = ax.bar(index, compress_nodes, bar_width, label=cases[0], alpha=0.8)
#      17 bar2 = ax.bar(index + bar_width, compress_depth, bar_width, label=cases[1], alpha=0.8)
#      19 plt.tick_params(axis='x', labelsize=4) # 调整x轴的字体大小
#
# IndexError: list index out of range
